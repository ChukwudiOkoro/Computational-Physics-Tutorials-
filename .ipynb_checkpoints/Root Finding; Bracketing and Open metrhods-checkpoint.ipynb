# %% [markdown]
# # Computational Techniques Root Finding and Bracketing Methods.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# Equation:  3x**3  + x-3 = 0
